# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-445e0337-9f57-42e2-b918-7f5311a62590" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-445e0337-9f57-42e2-b918-7f5311a62590">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Pune house data.csv.xls')

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.head(5)
# Out:
#               area_type   availability       size  society total_sqft  bath  \
# 0  Super built-up  Area         19-Dec      2 BHK  Coomee        1056   2.0
# 1            Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600   5.0
# 2        Built-up  Area  Ready To Move      3 BHK      NaN       1440   2.0
# 3  Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521   3.0
# 4  Super built-up  Area  Ready To Move      2 BHK      NaN       1200   2.0
#
#    balcony   price    site_location
# 0      1.0   39.07      Alandi Road
# 1      3.0  120.00  Ambegaon Budruk
# 2      3.0   62.00       Anandnagar
# 3      1.0   95.00            Aundh
# 4      1.0   51.00       Aundh Road

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      13320 non-null  object
#  1   availability   13320 non-null  object
#  2   size           13304 non-null  object
#  3   society        7818 non-null   object
#  4   total_sqft     13320 non-null  object
#  5   bath           13247 non-null  float64
#  6   balcony        12711 non-null  float64
#  7   price          13320 non-null  float64
#  8   site_location  13319 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
for column in df.columns:
  print(df[column].value_counts())
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: availability, Length: 81, dtype: int64
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# ...

# %%
df.isna().sum()
# Out:
# area_type           0
# availability        0
# size               16
# society          5502
# total_sqft          0
# bath               73
# balcony           609
# price               0
# site_location       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      13320 non-null  object
#  1   availability   13320 non-null  object
#  2   size           13304 non-null  object
#  3   society        7818 non-null   object
#  4   total_sqft     13320 non-null  object
#  5   bath           13247 non-null  float64
#  6   balcony        12711 non-null  float64
#  7   price          13320 non-null  float64
#  8   site_location  13319 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df['size'].isna().value_counts()
# Out:
# False    13304
# True        16
# Name: size, dtype: int64

# %%
df['size']=df['size'].fillna('2 BHK')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      13320 non-null  object
#  1   availability   13320 non-null  object
#  2   size           13320 non-null  object
#  3   society        7818 non-null   object
#  4   total_sqft     13320 non-null  object
#  5   bath           13247 non-null  float64
#  6   balcony        12711 non-null  float64
#  7   price          13320 non-null  float64
#  8   site_location  13319 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df['bhk']=df['size'].str.split().str.get(0).astype(int)

# %%
df['bhk'].astype(int)
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: bhk, Length: 13320, dtype: int64

# %%
df[df.bhk > 20]
# Out:
#                  area_type   availability        size society total_sqft  \
# 1718  Super built-up  Area  Ready To Move      27 BHK     NaN       8000
# 4684            Plot  Area  Ready To Move  43 Bedroom     NaN       2400
#
#       bath  balcony  price  site_location  bhk
# 1718  27.0      0.0  230.0  Uruli Devachi   27
# 4684  40.0      0.0  660.0  Salunke Vihar   43

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def convRangeval(x):
  temp=x.split('-')
  if len(temp) == 2:
    return (float(temp[0])+float(temp[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
df['total_sqft']=df['total_sqft'].apply(convRangeval)

# %%
df.head()
# Out:
#               area_type   availability       size  society  total_sqft  bath  \
# 0  Super built-up  Area         19-Dec      2 BHK  Coomee       1056.0   2.0
# 1            Plot  Area  Ready To Move  4 Bedroom  Theanmp      2600.0   5.0
# 2        Built-up  Area  Ready To Move      3 BHK      NaN      1440.0   2.0
# 3  Super built-up  Area  Ready To Move      3 BHK  Soiewre      1521.0   3.0
# 4  Super built-up  Area  Ready To Move      2 BHK      NaN      1200.0   2.0
#
#    balcony   price    site_location  bhk
# 0      1.0   39.07      Alandi Road    2
# 1      3.0  120.00  Ambegaon Budruk    4
# 2      3.0   62.00       Anandnagar    3
# 3      1.0   95.00            Aundh    3
# 4      1.0   51.00       Aundh Road    2

# %%
df['price_per_sqft']=df['price']*100000/df['total_sqft']

# %%
df['price_per_sqft']
# Out:
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
#              ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
# Name: price_per_sqft, Length: 13320, dtype: float64

# %%
 df.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  13274.000000  13247.000000  12711.000000  13320.000000  13320.000000
# mean    1559.626694      2.692610      1.584376    112.565627      2.802778
# std     1238.405258      1.341458      0.817263    148.971674      1.294496
# min        1.000000      1.000000      0.000000      8.000000      1.000000
# 25%     1100.000000      2.000000      1.000000     50.000000      2.000000
# 50%     1276.000000      2.000000      2.000000     72.000000      3.000000
# 75%     1680.000000      3.000000      2.000000    120.000000      3.000000
# max    52272.000000     40.000000      3.000000   3600.000000     43.000000
#
#        price_per_sqft
# count    1.327400e+04
# mean     7.907501e+03
# std      1.064296e+05
# min      2.678298e+02
# 25%      4.266865e+03
# 50%      5.434306e+03
# 75%      7.311746e+03
# max      1.200000e+07

# %%
df['bath']=df['bath'].fillna(df['bath'].median())

# %%
df=df[(df['total_sqft']/df['bhk'])>=300]

# %%
df.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  12530.000000  12530.000000  12014.000000  12530.000000  12530.000000
# mean    1594.564544      2.559537      1.587648    111.382401      2.650838
# std     1261.271296      1.077938      0.808842    152.077329      0.976678
# min      300.000000      1.000000      0.000000      8.440000      1.000000
# 25%     1116.000000      2.000000      1.000000     49.000000      2.000000
# 50%     1300.000000      2.000000      2.000000     70.000000      3.000000
# 75%     1700.000000      3.000000      2.000000    115.000000      3.000000
# max    52272.000000     16.000000      3.000000   3600.000000     16.000000
#
#        price_per_sqft
# count    12530.000000
# mean      6303.979357
# std       4162.237981
# min        267.829813
# 25%       4210.526316
# 50%       5294.117647
# 75%       6916.666667
# max     176470.588235

# %%
df.price_per_sqft.describe()
# Out:
# count     12530.000000
# mean       6303.979357
# std        4162.237981
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def outboundry(df):
  df_output=pd.DataFrame()
  for key,subdf in df.groupby('site_location'):
    mean=np.mean(subdf.price_per_sqft)
    std=np.std(subdf.price_per_sqft)
    gen_df=subdf[(subdf.price_per_sqft > (mean-std)) & (subdf.price_per_sqft <= (mean+std))]
    df_output= pd.concat([df_output,gen_df],ignore_index=True)
  return df_output

df=outboundry(df)

# %%
df.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  10945.000000  10945.000000  10580.000000  10945.000000  10945.000000
# mean    1491.737275      2.456921      1.592722     83.928549      2.565829
# std      854.321068      0.961994      0.796772     66.184050      0.895327
# min      300.000000      1.000000      0.000000     10.000000      1.000000
# 25%     1105.000000      2.000000      1.000000     48.000000      2.000000
# 50%     1278.000000      2.000000      2.000000     65.000000      2.000000
# 75%     1630.000000      3.000000      2.000000     96.000000      3.000000
# max    30400.000000     16.000000      3.000000   2100.000000     16.000000
#
#        price_per_sqft
# count    10945.000000
# mean      5381.477834
# std       1606.410143
# min       1379.310345
# 25%       4186.046512
# 50%       5108.359133
# 75%       6333.333333
# max      17548.524329

# %%
def bhk_outboundry(df):

  exclude_indices = np.array([])
  for location, location_df in df.groupby('site_location'):

    bhk_stats = {}
    for bhk, bhk_df in location_df.groupby('bhk'):
      bhk_stats[bhk] = {
      'mean': np.mean (bhk_df.price_per_sqft),
      'std': np.std(bhk_df.price_per_sqft),
      'count': bhk_df. shape [0]
      }
  for bhk, bhk_df in location_df.groupby('bhk'):
    stats = bhk_stats.get(bhk-1)
    if stats and stats ['count']>5:
      exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
  return df.drop(exclude_indices,axis='index')

# %%
df=bhk_outboundry(df)

# %%
df.shape
# Out:
# (10891, 11)

# %%
df
# Out:
#                   area_type   availability       size  society  total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee       1056.0
# 1                Plot  Area  Ready To Move  4 Bedroom  Goardth      2894.0
# 2      Super built-up  Area  Ready To Move      2 BHK  Bhinglv      1084.0
# 3      Super built-up  Area  Ready To Move      2 BHK  Aahts H      1230.0
# 4      Super built-up  Area  Ready To Move      3 BHK      NaN      1750.0
# ...                     ...            ...        ...      ...         ...
# 10933  Super built-up  Area  Ready To Move      4 BHK  Prtanha      3122.0
# 10936        Built-up  Area  Ready To Move  6 Bedroom      NaN      3500.0
# 10939        Built-up  Area         18-Mar  5 Bedroom  Toainnt      3210.0
# 10940  Super built-up  Area  Ready To Move      2 BHK  Jaw 2 L      1050.0
# 10944  Super built-up  Area         18-Apr      2 BHK      NaN      1132.0
#
#        bath  balcony   price site_location  bhk  price_per_sqft
# ...

# %% [markdown]
# No Need of price per sqft

# %%
df.drop(columns=['society','area_type','availability'],inplace=True)
df.drop(columns=['size','price_per_sqft'],inplace=True)

# %%
df.drop(columns=['balcony'],inplace=True)

# %%
df.isna().sum()
# Out:
# total_sqft       0
# bath             0
# price            0
# site_location    0
# bhk              0
# dtype: int64

# %%
df
# Out:
#        total_sqft  bath   price site_location  bhk
# 0          1056.0   2.0   39.07   Alandi Road    2
# 1          2894.0   4.0  245.00   Alandi Road    4
# 2          1084.0   2.0   50.00   Alandi Road    2
# 3          1230.0   2.0   80.00   Alandi Road    2
# 4          1750.0   3.0  130.00   Alandi Road    3
# ...           ...   ...     ...           ...  ...
# 10933      3122.0   6.0  250.00      Yerawada    4
# 10936      3500.0   6.0  115.00      Yerawada    6
# 10939      3210.0   2.0  353.00      Yerawada    5
# 10940      1050.0   2.0   54.00      Yerawada    2
# 10944      1132.0   2.0   70.00      Yerawada    2
#
# [10891 rows x 5 columns]

# %%
df.to_csv("CleanedPrices.csv")

# %%
 X=df.drop(columns=['price'])
Y=df['price']

# %%
X
# Out:
#        total_sqft  bath site_location  bhk
# 0          1056.0   2.0   Alandi Road    2
# 1          2894.0   4.0   Alandi Road    4
# 2          1084.0   2.0   Alandi Road    2
# 3          1230.0   2.0   Alandi Road    2
# 4          1750.0   3.0   Alandi Road    3
# ...           ...   ...           ...  ...
# 10933      3122.0   6.0      Yerawada    4
# 10936      3500.0   6.0      Yerawada    6
# 10939      3210.0   2.0      Yerawada    5
# 10940      1050.0   2.0      Yerawada    2
# 10944      1132.0   2.0      Yerawada    2
#
# [10891 rows x 4 columns]

# %%
Y
# Out:
# 0         39.07
# 1        245.00
# 2         50.00
# 3         80.00
# 4        130.00
#           ...
# 10933    250.00
# 10936    115.00
# 10939    353.00
# 10940     54.00
# 10944     70.00
# Name: price, Length: 10891, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge 
from sklearn.preprocessing import OneHotEncoder, StandardScaler 
from sklearn.compose import make_column_transformer 
from sklearn.pipeline import make_pipeline 
from sklearn.metrics import r2_score

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (8712, 4)

# %%
X_test.shape
# Out:
# (2179, 4)

# %% [markdown]
# Applying Linear Regression

# %%
column_trans = make_column_transformer ((OneHotEncoder (sparse=False), ['site_location']),remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
from sklearn.metrics.pairwise import normalize
model_lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,scaler,model_lr)

# %%
pipe.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['site_location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr=pipe.predict(X_test)

# %%
r2_score(Y_test,y_pred_lr)
# Out:
# 0.7811474413535395

# %%
lasso=Lasso()

# %%
pipe2=make_pipeline(column_trans,scaler,lasso)

# %%
pipe2.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['site_location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso=pipe2.predict(X_test)

# %%
r2_score(Y_test,y_pred_lasso)
# Out:
# 0.7804467355770606

# %%
ridge=Ridge()

# %%
pipe3=make_pipeline(column_trans,scaler,ridge)

# %%
pipe3.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['site_location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge=pipe3.predict(X_test)

# %%
r2_score(Y_test,y_pred_ridge)
# Out:
# 0.7811487447503483

# %%
import pickle

# %%
pickle.dump(pipe,open('Ridgemodel.pkl','wb'))

# %%
files.download('Ridgemodel.pkl')

# %%
files.download('CleanedPrices.csv')
